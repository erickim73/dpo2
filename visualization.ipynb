# %% [markdown]
# **VISUALIZATION**

# %%
import importlib
import tests
importlib.reload(tests)
from tests import visualize_util, visualize

import imageio
from pathlib import Path
import numpy as np

from utils import get_environment, setup_dpo_model
import benchmarks.sb3_utils 
importlib.reload(benchmarks.sb3_utils)

from benchmarks.sb3_utils import setup_benchmark_model
import envs
importlib.reload(envs)
importlib.reload(envs.molecule)
importlib.reload(envs.shape)

from envs import Shape, ShapeBoundary, Molecule
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python312.ubuntu 2025.23+release.e6f643b818cda63c8e00156a266c408faac3c3dd 2025-05-28T17:24:52] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# ...

# %%
def visualize_util(method, env, env_name, num_step, extra_args):
    if method.startswith('DPO'):
        model = setup_dpo_model(method, env, env_name)
        benchmark_model = False
    else:
        model = setup_benchmark_model(method, env, env_name)
        benchmark_model = True
    benchmark_str = '_benchmark' if benchmark_model else ''
    img_path = 'output/videos/' + env_name + benchmark_str + '_result.wmv'
    if 'molecule' in env_name:
        img_path = None
    visualize(env, model, num_step=num_step, benchmark_model=benchmark_model,
              extra_args=extra_args, img_path=img_path)

# %%
for model in ['DPO_zero_order']:
    env = ShapeBoundary(render_mode='rgb_array', max_num_step=500)
    visualize_util(model, env, 'shape_boundary', 500, 'half_random')
    env.close()
# Out:
# Saving to: output/videos/shape-boundary_DPO_zero_order.mp4
# Starting visualization: 500 steps
# Episode finished at step 500
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 600) to (608, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape-boundary_DPO_zero_order.mp4
#   Frames: 500, Quality: high
#   Final reward: 10391537.545

# %%
for model in ['DPO_zero_order']:
    env = ShapeBoundary(render_mode='rgb_array', max_num_step=200)
    visualize_util(model, env, 'shape_boundary', 200, 'ellipse')  
    env.close()
# Out:
# Saving to: output/videos/shape-boundary_DPO_zero_order.mp4
# Starting visualization: 200 steps
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 600) to (608, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode finished at step 200
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape-boundary_DPO_zero_order.mp4
#   Frames: 200, Quality: high
#   Final reward: -11330.889

# %%
for model in ['DPO_zero_order']:
    env = ShapeBoundary(render_mode='rgb_array', max_num_step=200)
    visualize_util(model, env, 'shape_boundary', 200, 'rect')  
    env.close()
# Out:
# Saving to: output/videos/shape-boundary_DPO_zero_order.mp4
# Starting visualization: 200 steps
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 600) to (608, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode finished at step 200
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape-boundary_DPO_zero_order.mp4
#   Frames: 200, Quality: high
#   Final reward: -12520.056

# %%
env2 = ShapeBoundary(render_mode='rgb_array', max_num_step=500)
visualize_util('TRPO_0_99', env2, 'shape_boundary_TRPO_0_99', 500, 'half_random')
env2.close()
# Out:
# /mnt/c/Users/DELL/dpo2/venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Saving to: output/videos/shape-boundary-TRPO-0-99_TRPO_0_99_benchmark.mp4
# Starting visualization: 500 steps
# Episode finished at step 500
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 600) to (608, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape-boundary-TRPO-0-99_TRPO_0_99_benchmark.mp4
# ...

# %%
# Visualization topological material deformation
env = Shape(render_mode='rgb_array', max_num_step=200)
visualize_util('DPO_zero_order', env, 'shape', 200, 'hole')
# Out:
# Saving to: output/videos/shape_DPO_zero_order.mp4
# Starting visualization: 200 steps
# Episode finished at step 200
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape_DPO_zero_order.mp4
#   Frames: 200, Quality: high
#   Final reward: -8952.871
# ([np.float64(7.285065266508099),
#   np.float64(7.2850652665081),
#   np.float64(7.2773629927071175),
#   np.float64(7.274800995089114),
#   np.float64(7.267131197495319),
#   np.float64(7.2645799840772245),
#   np.float64(7.242706696695365),
#   np.float64(7.240170290840418),
#   np.float64(7.235105463154569),
#   np.float64(7.203131029229697),
#   np.float64(7.200620790077241),
#   np.float64(7.193105786670743),
#   np.float64(7.188108838664629),
#   np.float64(7.185614263580802),
#   np.float64(7.151394616845825),
#   np.float64(7.103160161628485),
#   np.float64(7.09826817746581),
#   np.float64(7.0836526568878275),
#   np.float64(7.0498867831223855),
#   np.float64(7.042672154386005),
# ...

# %%
# Visualization topological material deformation
env = Shape(render_mode='rgb_array', max_num_step=200)
visualize_util('DPO_zero_order', env, 'shape', 200, 'random_with_padding')
# Out:
# Saving to: output/videos/shape_DPO_zero_order.mp4
# Starting visualization: 200 steps
# Episode finished at step 200
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape_DPO_zero_order.mp4
#   Frames: 200, Quality: high
#   Final reward: 5113.835
# ([np.float64(7.5068159622040715),
#   np.float64(7.5045213523500065),
#   np.float64(7.518112909596367),
#   np.float64(7.518112909596367),
#   np.float64(7.502109619021042),
#   np.float64(7.499831765736707),
#   np.float64(7.4862080760245755),
#   np.float64(7.439058498210095),
#   np.float64(7.414622225325633),
#   np.float64(7.399066282565783),
#   np.float64(7.4056443847699445),
#   np.float64(7.372189687702918),
#   np.float64(7.341521892406195),
#   np.float64(7.332833700672701),
#   np.float64(7.324176278881082),
#   np.float64(7.348947320185173),
#   np.float64(7.333916583895053),
#   np.float64(7.306245341568921),
#   np.float64(7.3066001847141635),
#   np.float64(7.279340568256585),
# ...

# %%
# Visualization topological material deformation
env = Shape(render_mode='rgb_array', max_num_step=500)
visualize_util('DPO_zero_order', env, 'shape', 500, 'hole')
visualize_util('TRPO_0_99', env, 'naive_shape_TRPO_0_99.zip', 500, 'hole')
# Out:
# Saving to: output/videos/shape_DPO_zero_order.mp4
# Starting visualization: 500 steps
# Episode finished at step 500
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/shape_DPO_zero_order.mp4
#   Frames: 500, Quality: high
#   Final reward: 607308.288
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /mnt/c/Users/DELL/dpo2/venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# Saving to: output/videos/naive-shape-TRPO-0-99_TRPO_0_99_benchmark.mp4
# Starting visualization: 500 steps
# Episode finished at step 500
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/naive-shape-TRPO-0-99_TRPO_0_99_benchmark.mp4
#   Frames: 500, Quality: high
# ...

# %%
# Visualization molecular dynamics
env_name = 'molecule'
env = get_environment(env_name)
visualize_util('DPO_zero_order', get_environment('molecule'), 'molecule', 200, 'random')
visualize_util('SAC_0_99', get_environment('naive_molecule'), 'naive_molecule_SAC_0_99', 200, 'random')
# Out:
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Saving to: output/videos/molecule_DPO_zero_order.mp4
# Starting visualization: 200 steps
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (300, 300) to (304, 304) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode finished at step 60
# Trying ffmpeg_writer...
# ✓ Saved with ffmpeg_writer
# ✓ Video saved: output/videos/molecule_DPO_zero_order.mp4
#   Frames: 60, Quality: high
#   Final reward: -127468.230
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Saving to: output/videos/naive-molecule-SAC-0-99_SAC_0_99_benchmark.mp4
# Starting visualization: 200 steps
# ...
